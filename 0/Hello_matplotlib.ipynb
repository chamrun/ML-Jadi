# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.plot([1, 2, 4])

# %%
plt.plot([1, 2, 4, 5], 'r+')

# %%
plt.plot([1, 2, 4, 5], 'r-.')

# %%
t = np.arange(1, 8, 0.5)
plt.plot(range(1, 8, 2), range(1, 8, 2), 'r-.', t, t**2, 'go', t, t**3, 'b^')

# %%
data = {
    'a': range(100),
    'b': np.random.randint(0, 100, 100),
    'c': np.random.randn(100)
}

# %%
plt.scatter(data['a'], data['b'])

# %%
plt.scatter(data['a'], data['c'])
