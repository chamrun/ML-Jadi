# %%
import pandas
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt



df = pandas.read_csv("FuelConsumption.csv")

model = linear_model.LinearRegression()

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS', 'FUELCONSUMPTION_COMB_MPG']]

msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# X = np.asanyarray(train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
X = np.asanyarray(train[['FUELCONSUMPTION_COMB_MPG']])
y = np.asanyarray(train[['CO2EMISSIONS']])

model.fit(X, y)

print('Variance score: %.2f' % model.score(X, y))

model = DecisionTreeClassifier()

plt.plot(df['ENGINESIZE'], df['CO2EMISSIONS'], 'bo')
# Out:
# Variance score: 0.37

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model.fit(X_train, y_train)

result = model.predict(X_test)

plt.scatter(y_test, result)

accuracy_score(y_test, result)
# Out:
# 0.33136094674556216
